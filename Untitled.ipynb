# %%
from figurefirst import svg_to_axes

# %%
reload(svg_to_axes)
# Out:
# <module 'figurefirst.svg_to_axes' from 'figurefirst/svg_to_axes.py'>

# %%
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
mpl_fig,ax_dict = svg_to_axes.read_svg_to_axes('download.svg')
# Out:
# <type 'unicode'>
# 218.000002
# 218.000002
# 218.000002

# %%
def from_mpl(fig):
    from StringIO import StringIO
    fid = StringIO()
    w,h = fig.get_size_inches()
    try:
        mpl_fig,ax_dict = svg_to_axes.read_svg_to_axes('download.svg')
        fig.savefig(fid, format='svg')
    except ValueError:
        raise(ValueError, "No matplotlib SVG backend")
    fid.seek(0);
    fig.savefig('test.svg')
    return fid

mpl_fig,ax_dict = svg_to_axes.read_svg_to_axes('download.svg')
svg_string = from_mpl(mpl_fig)
from xml.dom import minidom
doc = minidom.parse(svg_string)
# Out:
# <type 'unicode'>
# 218.000002
# 218.000002
# 218.000002
# <type 'unicode'>
# 218.000002
# 218.000002
# 218.000002

# %%
print doc.toxml()
# Out:
# <?xml version="1.0" ?><!DOCTYPE svg  PUBLIC '-//W3C//DTD SVG 1.1//EN'  'http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd'><!-- Created with matplotlib (http://matplotlib.org/) --><svg height="720pt" version="1.1" viewBox="0 0 720 720" width="720pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d=" M0 720 L720 720 L720 0 L0 0 z " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d=" M3.31776e+06 -5.27378e+07 L1.83859e+07 -5.27378e+07 L1.83859e+07 -6.29676e+07 L3.31776e+06 -6.29676e+07 z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path d=" M3.31776e+06 -6.29676e+07" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
# ...

# %%
svg = doc.childNodes[2]

# %%
print svg.childNodes[3].toxml()
# Out:
# <g id="figure_1">
#   <g id="patch_1">
#    <path d=" M0 720 L720 720 L720 0 L0 0 z " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d=" M3.31776e+06 -5.27378e+07 L1.83859e+07 -5.27378e+07 L1.83859e+07 -6.29676e+07 L3.31776e+06 -6.29676e+07 z " style="fill:#ffffff;"/>
#    </g>
#    <g id="patch_3">
#     <path d=" M3.31776e+06 -6.29676e+07" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d=" M1.83859e+07 -5.27378e+07" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d=" M3.31776e+06 -5.27378e+07" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d=" M3.31776e+06 -5.27378e+07" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
# ...

# %%
fig.get_size_inches()
# Out:
# array([ 10. ,   7.5])
